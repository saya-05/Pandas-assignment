# %%
import pandas as pd

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts','Lion'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd','3rd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35,42],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9,3],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523,1234],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345,421],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3,2],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1,1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3,4],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia','Alaska']}

# %%
raw_data
# Out:
# {'regiment': ['Nighthawks',
#   'Nighthawks',
#   'Nighthawks',
#   'Nighthawks',
#   'Dragoons',
#   'Dragoons',
#   'Dragoons',
#   'Dragoons',
#   'Scouts',
#   'Scouts',
#   'Scouts',
#   'Scouts',
#   'Lion'],
#  'company': ['1st',
#   '1st',
#   '2nd',
#   '2nd',
#   '1st',
#   '1st',
#   '2nd',
#   '2nd',
#   '1st',
#   '1st',
#   '2nd',
#   '2nd',
#   '3rd'],
#  'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35, 42],
#  'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9, 3],
#  'size': [1045,
#   957,
#   1099,
#   1400,
#   1592,
#   1006,
#   987,
#   849,
#   973,
#   1005,
#   1099,
#   1523,
#   1234],
#  'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345, 421],
#  'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3, 2],
#  'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1, 1],
#  'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3, 4],
#  'origin': ['Arizona',
#   'California',
#   'Texas',
#   'Florida',
#   'Maine',
#   'Iowa',
#   'Alaska',
# ...

# %%
#Create a dataframe and assign it to a variable called army.
army = pd.DataFrame(raw_data)

# %%
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %%
#Set the 'origin' colum as the index of the dataframe
army.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
army.index = army['origin']

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# ...

# %%
army.loc['Alaska',:]
# Out:
#         regiment company  deaths  battles  size  veterans  readiness  armored  \
# origin
# Alaska  Dragoons     2nd     523        8   987       949          2        0
# Alaska      Lion     3rd      42        3  1234       421          2        1
#
#         deserters  origin
# origin
# Alaska         24  Alaska
# Alaska          4  Alaska

# %%
#Print only the column veterans
army['veterans']
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Alaska        421
# Name: veterans, dtype: int64

# %%
#Print the columns 'veterans' and 'deaths'
army[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35
# Alaska           421      42

# %%
#Print the name of all the columns
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters', 'origin'],
#       dtype='object')

# %%
# Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska
army.loc[army.origin.isin(['Maine','Alaska']),['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24
# Alaska      42  1234          4

# %%
army.loc[['Maine','Alaska'],['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24
# Alaska      42  1234          4

# %%
#Select the rows 3 to 7 and the columns 3 to 6
army.iloc[2:7,2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %%
#Select every row after the fourth row
army.iloc[3:,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
# Alaska            Lion     3rd      42        3  1234       421          2
#
#             armored  deserters      origin
# origin
# Florida           1          2     Florida
# ...

# %%
#Select every row up to the 4th row
army.iloc[:4,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters      origin
# origin
# Arizona           1          4     Arizona
# California        0         24  California
# Texas             1         31       Texas
# Florida           1          2     Florida

# %%
#Select the 3rd column up to the 7th column
army.iloc[:,2:7]
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Arizona        523        5  1045         1          1
# California      52       42   957         5          2
# Texas           25        2  1099        62          3
# Florida        616        2  1400        26          3
# Maine           43        4  1592        73          2
# Iowa           234        7  1006        37          1
# Alaska         523        8   987       949          2
# Washington      62        3   849        48          3
# Oregon          62        4   973        48          2
# Wyoming         73        7  1005       435          1
# Louisana        37        8  1099        63          2
# Georgia         35        9  1523       345          3
# Alaska          42        3  1234       421          2

# %%
#Select rows where df.deaths is greater than 50
army[army['deaths']>50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters      origin
# origin
# Arizona           1          4     Arizona
# California        0         24  California
# Florida           1          2     Florida
# Iowa              1          4        Iowa
# Alaska            0         24      Alaska
# ...

# %%
#Select rows where df.deaths is greater than 500 or less than 50
army[((army['deaths']>500) | (army['deaths']<50))]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
# Alaska          Lion     3rd      42        3  1234       421          2
#
#           armored  deserters    origin
# origin
# Arizona         1          4   Arizona
# Texas           1         31     Texas
# Florida         1          2   Florida
# Maine           0          3     Maine
# Alaska          0         24    Alaska
# Louisana        1          2  Louisana
# ...

# %%
#Select all the regiments not named "Dragoons"
army[army['regiment']!= 'Dragoons']
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
# Alaska            Lion     3rd      42        3  1234       421          2
#
#             armored  deserters      origin
# origin
# Arizona           1          4     Arizona
# California        0         24  California
# Texas             1         31       Texas
# ...

# %%
#Select the rows called Texas and Arizona
army.loc[['Texas','Arizona'],:]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters   origin
# origin
# Texas          1         31    Texas
# Arizona        1          4  Arizona

# %%
# Select the third cell in the row named Arizona
army.loc[['Arizona'],'deaths']
# Out:
# origin
# Arizona    523
# Name: deaths, dtype: int64

# %%
#Select the third cell down in the column named deaths
army.iloc[2,2]
# Out:
# 25
